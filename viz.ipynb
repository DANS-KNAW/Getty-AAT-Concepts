# %%
from graphviz import Digraph

dot = Digraph()

# Set the direction of the tree to horizontal
dot.attr(rankdir='LR')

# Define nodes for each facet and its associated concepts
dot.node('A', 'ASSOCIATED CONCEPT FACET')
dot.node('AC', 'Associated Concepts')

dot.node('P', 'PHYSICAL ATTRIBUTES FACET')
dot.node('AP', 'Attributes and Properties')
dot.node('CE', 'Conditions and Effects')
dot.node('DE', 'Design Elements')
dot.node('C', 'Color')

dot.node('SP', 'STYLES AND PERIODS FACET')
dot.node('SPC', 'Styles and Periods')

dot.node('AG', 'AGENTS FACET')
dot.node('PE', 'People')
dot.node('O', 'Organizations')
dot.node('LO', 'Living Organisms')

dot.node('ACV', 'ACTIVITIES FACET')
dot.node('D', 'Disciplines')
dot.node('F', 'Functions')
dot.node('E', 'Events')
dot.node('PMA', 'Physical and Mental Activities')
dot.node('PT', 'Processes and Techniques')

dot.node('M', 'MATERIALS FACET')
dot.node('MT', 'Materials')

dot.node('O2', 'OBJECTS FACET')
dot.node('OGS', 'Object Groupings and Systems')
dot.node('OG', 'Object Genres')
dot.node('C1', 'Components')

# Built Environment
dot.node('BE', '*Built Environment*')
dot.node('S', 'Settlements and Landscapes')
dot.node('BC', 'Built Complexes and Districts')
dot.node('SBW', 'Single Built Works')
dot.node('OS', 'Open Spaces and Site Elements')

# Furnishings and Equipment
dot.node('FE', '*Furnishings and Equipment*')
dot.node('F', 'Furnishings')
dot.node('CST', 'Costume')
dot.node('TE', 'Tools and Equipment')
dot.node('W', 'Weapons and Ammunition')
dot.node('MD', 'Measuring Devices')
dot.node('CN', 'Containers')
dot.node('SD', 'Sound Devices')
dot.node('RA', 'Recreational Artifacts')
dot.node('TV', 'Transportation Vehicles')

# Visual and Verbal Communication
dot.node('VC', '*Visual and Verbal Communication*')
dot.node('VW', 'Visual Works')
dot.node('EM', 'Exchange Media')
dot.node('IF', 'Information Forms')

dot.node('BN', 'BRAND NAMES FACET')
dot.node('BN2', 'Brand Names')

# Define edges to create hierarchy
dot.edge('A', 'AC')
dot.edge('P', 'AP')
dot.edge('P', 'CE')
dot.edge('P', 'DE')
dot.edge('P', 'C')
dot.edge('SP', 'SPC')
dot.edge('AG', 'PE')
dot.edge('AG', 'O')
dot.edge('AG', 'LO')
dot.edge('ACV', 'D')
dot.edge('ACV', 'F')
dot.edge('ACV', 'E')
dot.edge('ACV', 'PMA')
dot.edge('ACV', 'PT')
dot.edge('M', 'MT')
dot.edge('O2', 'OGS')
dot.edge('O2', 'OG')
dot.edge('O2', 'C1')

# Built Environment edges
dot.edge('O2', 'BE')
dot.edge('BE', 'S')
dot.edge('BE', 'BC')
dot.edge('BE', 'SBW')
dot.edge('BE', 'OS')

# Furnishings and Equipment edges
dot.edge('O2', 'FE')
dot.edge('FE', 'F')
dot.edge('FE', 'CST')
dot.edge('FE', 'TE')
dot.edge('FE', 'W')
dot.edge('FE', 'MD')
dot.edge('FE', 'CN')
dot.edge('FE', 'SD')
dot.edge('FE', 'RA')
dot.edge('FE', 'TV')

# Visual and Verbal Communication edges
dot.edge('O2', 'VC')
dot.edge('VC', 'VW')
dot.edge('VC', 'EM')
dot.edge('VC', 'IF')

dot.edge('BN', 'BN2')

# Render the tree
dot.render('taxonomy_tree', format='plain', cleanup=True)
dot

# %% [markdown]
# # Getty AAT
